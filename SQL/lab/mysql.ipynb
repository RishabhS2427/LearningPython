# %%
# !pip3 install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sqlalchemy in /Users/sam/Library/Python/3.9/lib/python/site-packages (2.0.49)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from sqlalchemy) (4.15.0)

# %%
import mysql.connector as sql
import pandas as pd
from sqlalchemy import create_engine

# %%
def csv_to_db(fileName,connection, table_name):
    df = pd.read_csv(fileName)
    df.to_sql(name=table_name, con=connection, if_exists ='append', index=False)

# %%
db_name= "SHOPS"
file_name = './input/PETSHOP.csv'
table_name = 'PETSHOP'
db_connection = create_engine(f'mysql+mysqlconnector://sam:test123@localhost:3306/{db_name}')
try:
 connection = sql.connect( host="localhost",
                     user="sam",
                     passwd="test123",
                     port=3306,
                     charset="utf8" )
 if connection.is_connected():
        print("Successfully connected to MySQL database")
        cursor = connection.cursor()
        cursor.execute(f"CREATE DATABASE IF NOT EXISTS {db_name};")
        cursor.execute("SHOW DATABASES")
        for db in cursor:
            print(db)
        cursor.execute(f"USE {db_name};")
        # Example query

except mysql.connector.Error as err:
       print(f"Error: {err}")

finally:
    print("Connection to MySQL successful")
# Out:
# Connection to MySQL successful
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (61)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[8], line 6
#       5 try:
# ----> 6  connection = sql.connect( host="localhost",
#       7                      user="sam",
#       8                      passwd="test123",
#       9                      port=3306,
#      10                      charset="utf8" )
#      11  if connection.is_connected():
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:142, in CMySQLConnection.__init__(self, **kwargs)
#     141 try:
# --> 142     self.connect(**kwargs)
#     143 except Exception:
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:360, in CMySQLConnection._open_connection(self)
#     359 if hasattr(err, "errno"):
# --> 360     raise get_mysql_exception(
#     361         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     362     ) from err
#     363 raise InterfaceError(str(err)) from err
#
# DatabaseError: 2003 (HY000): Can't connect to MySQL server on 'localhost:3306' (61)
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 21
#      18         cursor.execute(f"USE {db_name};")
#      19         # Example query
# ---> 21 except mysql.connector.Error as err:
#      22        print(f"Error: {err}")
#      24 finally:
#
# NameError: name 'mysql' is not defined

# %%
def run_query(query):
    print('Statement : ',query)
    results = pd.read_sql(query, con=db_connection)
    print("Output:\n ", results)

# %%
def run_on_direct_db(query, connection):
   if connection.is_connected():
     cursor = connection.cursor()
     cursor.execute(query)
     connection.commit()

# %%
csv_to_db(file_name,db_connection, table_name)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (61)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:3317, in Engine.raw_connection(self)
#    3296 """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298 The returned object is a proxied version of the DBAPI
#    (...)
#    3315
#    3316 """
# -> 3317 return self.pool.connect()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)
#     446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py:178, in QueuePool._do_get(self)
#     177 with util.safe_reraise():
# --> 178     self._dec_overflow()
#     179 raise
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     900     with util.safe_reraise():
# --> 901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:142, in CMySQLConnection.__init__(self, **kwargs)
#     141 try:
# --> 142     self.connect(**kwargs)
#     143 except Exception:
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:360, in CMySQLConnection._open_connection(self)
#     359 if hasattr(err, "errno"):
# --> 360     raise get_mysql_exception(
#     361         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     362     ) from err
#     363 raise InterfaceError(str(err)) from err
#
# DatabaseError: 2003 (HY000): Can't connect to MySQL server on 'localhost:3306' (61)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 csv_to_db(file_name,db_connection, table_name)
#
# Cell In[6], line 3, in csv_to_db(fileName, connection, table_name)
#       1 def csv_to_db(fileName,connection, table_name):
#       2     df = pd.read_csv(fileName)
# ----> 3     df.to_sql(name=table_name, con=connection, if_exists ='append', index=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:3109, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2911 """
#    2912 Write records stored in a DataFrame to a SQL database.
#    2913
#    (...)
#    3105 [(1,), (None,), (2,)]
#    3106 """  # noqa: E501
#    3107 from pandas.io import sql
# -> 3109 return sql.to_sql(
#    3110     self,
#    3111     name,
#    3112     con,
#    3113     schema=schema,
#    3114     if_exists=if_exists,
#    3115     index=index,
#    3116     index_label=index_label,
#    3117     chunksize=chunksize,
#    3118     dtype=dtype,
#    3119     method=method,
#    3120 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:843, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     838 elif not isinstance(frame, DataFrame):
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
# --> 843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#    (...)
#     855         **engine_kwargs,
#     856     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:908, in pandasSQL_builder(con, schema, need_transaction)
#     905     raise ImportError("Using URI string without sqlalchemy installed.")
#     907 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 908     return SQLDatabase(con, schema, need_transaction)
#     910 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     911 if adbc and isinstance(con, adbc.Connection):
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:1648, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1646     self.exit_stack.callback(con.dispose)
#    1647 if isinstance(con, Engine):
# -> 1648     con = self.exit_stack.enter_context(con.connect())
#    1649 if need_transaction and not con.in_transaction():
#    1650     self.exit_stack.enter_context(con.begin())
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:3293, in Engine.connect(self)
#    3270 def connect(self) -> Connection:
#    3271     """Return a new :class:`_engine.Connection` object.
#    3272
#    3273     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3290
#    3291     """
# -> 3293     return self._connection_cls(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:2448, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2446 elif should_wrap:
#    2447     assert sqlalchemy_exception is not None
# -> 2448     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2449 else:
#    2450     assert exc_info[1] is not None
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:3317, in Engine.raw_connection(self)
#    3295 def raw_connection(self) -> PoolProxiedConnection:
#    3296     """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298     The returned object is a proxied version of the DBAPI
#    (...)
#    3315
#    3316     """
# -> 3317     return self.pool.connect()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)
#     446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)
#    1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py:178, in QueuePool._do_get(self)
#     176     except:
#     177         with util.safe_reraise():
# --> 178             self._dec_overflow()
#     179         raise
#     180 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
#     900     with util.safe_reraise():
# --> 901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#     905     if pool.dispatch.first_connect:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:142, in CMySQLConnection.__init__(self, **kwargs)
#     140 if kwargs:
#     141     try:
# --> 142         self.connect(**kwargs)
#     143     except Exception:
#     144         self.close()
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1601     self.config(**kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#    1610 if charset or collation:
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:360, in CMySQLConnection._open_connection(self)
#     358 except MySQLInterfaceError as err:
#     359     if hasattr(err, "errno"):
# --> 360         raise get_mysql_exception(
#     361             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     362         ) from err
#     363     raise InterfaceError(str(err)) from err
#     365 self._do_handshake()
#
# DatabaseError: (mysql.connector.errors.DatabaseError) 2003 (HY000): Can't connect to MySQL server on 'localhost:3306' (61)
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
run_query(f"SELECT * FROM {table_name};")
# Out:
# Statement :  SELECT * FROM PETSHOP;
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (61)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:3317, in Engine.raw_connection(self)
#    3296 """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298 The returned object is a proxied version of the DBAPI
#    (...)
#    3315
#    3316 """
# -> 3317 return self.pool.connect()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)
#     446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py:178, in QueuePool._do_get(self)
#     177 with util.safe_reraise():
# --> 178     self._dec_overflow()
#     179 raise
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     900     with util.safe_reraise():
# --> 901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:142, in CMySQLConnection.__init__(self, **kwargs)
#     141 try:
# --> 142     self.connect(**kwargs)
#     143 except Exception:
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:360, in CMySQLConnection._open_connection(self)
#     359 if hasattr(err, "errno"):
# --> 360     raise get_mysql_exception(
#     361         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     362     ) from err
#     363 raise InterfaceError(str(err)) from err
#
# DatabaseError: 2003 (HY000): Can't connect to MySQL server on 'localhost:3306' (61)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 run_query(f"SELECT * FROM {table_name};")
#
# Cell In[9], line 3, in run_query(query)
#       1 def run_query(query):
#       2     print('Statement : ',query)
# ----> 3     results = pd.read_sql(query, con=db_connection)
#       4     print("Output:\n ", results)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     703     dtype_backend = "numpy"  # type: ignore[assignment]
#     704 assert dtype_backend is not lib.no_default
# --> 706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
#     708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#    (...)
#     716             dtype=dtype,
#     717         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:908, in pandasSQL_builder(con, schema, need_transaction)
#     905     raise ImportError("Using URI string without sqlalchemy installed.")
#     907 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 908     return SQLDatabase(con, schema, need_transaction)
#     910 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     911 if adbc and isinstance(con, adbc.Connection):
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:1648, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1646     self.exit_stack.callback(con.dispose)
#    1647 if isinstance(con, Engine):
# -> 1648     con = self.exit_stack.enter_context(con.connect())
#    1649 if need_transaction and not con.in_transaction():
#    1650     self.exit_stack.enter_context(con.begin())
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:3293, in Engine.connect(self)
#    3270 def connect(self) -> Connection:
#    3271     """Return a new :class:`_engine.Connection` object.
#    3272
#    3273     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3290
#    3291     """
# -> 3293     return self._connection_cls(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:2448, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2446 elif should_wrap:
#    2447     assert sqlalchemy_exception is not None
# -> 2448     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2449 else:
#    2450     assert exc_info[1] is not None
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:3317, in Engine.raw_connection(self)
#    3295 def raw_connection(self) -> PoolProxiedConnection:
#    3296     """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298     The returned object is a proxied version of the DBAPI
#    (...)
#    3315
#    3316     """
# -> 3317     return self.pool.connect()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)
#     446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)
#    1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py:178, in QueuePool._do_get(self)
#     176     except:
#     177         with util.safe_reraise():
# --> 178             self._dec_overflow()
#     179         raise
#     180 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
#     900     with util.safe_reraise():
# --> 901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#     905     if pool.dispatch.first_connect:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:142, in CMySQLConnection.__init__(self, **kwargs)
#     140 if kwargs:
#     141     try:
# --> 142         self.connect(**kwargs)
#     143     except Exception:
#     144         self.close()
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1601     self.config(**kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#    1610 if charset or collation:
#
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:360, in CMySQLConnection._open_connection(self)
#     358 except MySQLInterfaceError as err:
#     359     if hasattr(err, "errno"):
# --> 360         raise get_mysql_exception(
#     361             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     362         ) from err
#     363     raise InterfaceError(str(err)) from err
#     365 self._do_handshake()
#
# DatabaseError: (mysql.connector.errors.DatabaseError) 2003 (HY000): Can't connect to MySQL server on 'localhost:3306' (61)
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
run_on_direct_db(f"DROP TABLE IF EXISTS BookShop;",connection)
# run_query(f"DROP TABLE IF EXISTS BookShop_AuthorDetails;")
run_on_direct_db(f"CREATE TABLE BookShop (BOOK_ID VARCHAR(4) NOT NULL, TITLE VARCHAR(100) NOT NULL, AUTHOR_NAME VARCHAR(30) NOT NULL, 	AUTHOR_BIO VARCHAR(250),AUTHOR_ID INTEGER NOT NULL, PUBLICATION_DATE DATE NOT NULL, PRICE_USD DECIMAL(6,2) CHECK(Price_USD>0) NOT NULL);",connection)

# %%
insert = f"INSERT INTO BookShop VALUES ('B101', 'Introduction to Algorithms', 'Thomas H. Cormen', 'Thomas H. Cormen is the co-author of Introduction to Algorithms, along with Charles Leiserson, Ron Rivest, and Cliff Stein. He is a Full Professor of computer science at Dartmouth College and currently Chair of the Dartmouth College Writing Program.', 123 , '2001-09-01', 125),('B201', 'Structure and Interpretation of Computer Programs', 'Harold Abelson', 'Harold Abelson, Ph.D., is Class of 1922 Professor of Computer Science and Engineering in the Department of Electrical Engineering and Computer Science at MIT and a fellow of the IEEE.', 456, '1996-07-25', 65.5),('B301', 'Deep Learning', 'Ian Goodfellow', 'Ian J. Goodfellow is a researcher working in machine learning, currently employed at Apple Inc. as its director of machine learning in the Special Projects Group. He was previously employed as a research scientist at Google Brain.', 369, '2016-11-01', 82.7),('B401', 'Algorithms Unlocked', 'Thomas H. Cormen', 'Thomas H. Cormen is the co-author of Introduction to Algorithms, along with Charles Leiserson, Ron Rivest, and Cliff Stein. He is a Full Professor of computer science at Dartmouth College and currently Chair of the Dartmouth College Writing Program.', 123, '2013-05-15', 36.5),('B501', 'Machine Learning: A Probabilistic Perspective', 'Kevin P. Murphy', '', 157, '2012-08-24', 46);"
run_on_direct_db(insert,connection)

# %%
run_query(f"SELECT * FROM BookShop;")
# Out:
# Statement :  SELECT * FROM BookShop;
# Output:
#     BOOK_ID                                              TITLE  \
# 0    B101                         Introduction to Algorithms
# 1    B201  Structure and Interpretation of Computer Programs
# 2    B301                                      Deep Learning
# 3    B401                                Algorithms Unlocked
# 4    B501      Machine Learning: A Probabilistic Perspective
# 5    B101                         Introduction to Algorithms
# 6    B201  Structure and Interpretation of Computer Programs
# 7    B301                                      Deep Learning
# 8    B401                                Algorithms Unlocked
# 9    B501      Machine Learning: A Probabilistic Perspective
#
#         AUTHOR_NAME                                         AUTHOR_BIO  \
# 0  Thomas H. Cormen  Thomas H. Cormen is the co-author of Introduct...
# 1    Harold Abelson  Harold Abelson, Ph.D., is Class of 1922 Profes...
# 2    Ian Goodfellow  Ian J. Goodfellow is a researcher working in m...
# 3  Thomas H. Cormen  Thomas H. Cormen is the co-author of Introduct...
# 4   Kevin P. Murphy
# 5  Thomas H. Cormen  Thomas H. Cormen is the co-author of Introduct...
# 6    Harold Abelson  Harold Abelson, Ph.D., is Class of 1922 Profes...
# 7    Ian Goodfellow  Ian J. Goodfellow is a researcher working in m...
# 8  Thomas H. Cormen  Thomas H. Cormen is the co-author of Introduct...
# 9   Kevin P. Murphy
#
#    AUTHOR_ID PUBLICATION_DATE  PRICE_USD
# 0        123       2001-09-01      125.0
# 1        456       1996-07-25       65.5
# 2        369       2016-11-01       82.7
# 3        123       2013-05-15       36.5
# 4        157       2012-08-24       46.0
# 5        123       2001-09-01      125.0
# 6        456       1996-07-25       65.5
# 7        369       2016-11-01       82.7
# 8        123       2013-05-15       36.5
# 9        157       2012-08-24       46.0

# %%
df  = pd.read_sql(f"TRUNCATE TABLE {table_name};",con=db_connection)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df  = pd.read_sql(f"TRUNCATE TABLE {table_name};",con=db_connection)
#       2 print(df)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:736, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     726     return pandas_sql.read_table(
#     727         sql,
#     728         index_col=index_col,
#    (...)
#     733         dtype_backend=dtype_backend,
#     734     )
#     735 else:
# --> 736     return pandas_sql.read_query(
#     737         sql,
#     738         index_col=index_col,
#     739         params=params,
#     740         coerce_float=coerce_float,
#     741         parse_dates=parse_dates,
#     742         chunksize=chunksize,
#     743         dtype_backend=dtype_backend,
#     744         dtype=dtype,
#     745     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:1849, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1802 """
#    1803 Read SQL query into a DataFrame.
#    1804
#    (...)
#    1846
#    1847 """
#    1848 result = self.execute(sql, params)
# -> 1849 columns = result.keys()
#    1851 if chunksize is not None:
#    1852     self.returns_generator = True
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/result.py:920, in _WithKeys.keys(self)
#     903 def keys(self) -> RMKeyView:
#     904     """Return an iterable view which yields the string keys that would
#     905     be represented by each :class:`_engine.Row`.
#     906
#    (...)
#     918
#     919     """
# --> 920     return self._metadata.keys
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/cursor.py:1476, in _NoResultMetaData.keys(self)
#    1474 @property
#    1475 def keys(self) -> NoReturn:
# -> 1476     self._we_dont_return_rows()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/cursor.py:1448, in _NoResultMetaData._we_dont_return_rows(self, err)
#    1445 def _we_dont_return_rows(
#    1446     self, err: Optional[BaseException] = None
#    1447 ) -> NoReturn:
# -> 1448     raise exc.ResourceClosedError(
#    1449         "This result object does not return rows. "
#    1450         "It has been closed automatically."
#    1451     ) from err
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# Load data from csv

# %%
load data infile

# %%
if 'connection' in locals() and connection.is_connected():
        cursor.close()
        connection.close()
        db_connection.dispose()
        print("MySQL connection is closed")
