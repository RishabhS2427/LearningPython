# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Hands-on Lab: Loading data with Pandas
#
# Estimated time needed: **30** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Use Pandas to access and view data

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li><a href="#About-the-Dataset">About the Dataset</a></li>
#         <li><a href="#Introduction-of-Pandas">Introduction of <code>Pandas</code></a></li>
#         <li><a href="#Viewing-Data-and-Accessing-Data">Viewing Data and Accessing Data</a></li>
#         <li><a href="#Quiz-on-DataFrame">Quiz on DataFrame</a></li>
#     </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# ## About the Dataset

# %% [markdown]
# The table has one row for each product and several columns.
#
# <ul>
#     <li><b>OrderID</b>: A unique identifier for each order</li>
#     <li><b>Product</b>: The name of the product purchased</li>
#     <li><b>Category</b>: The category to which the product belongs (e.g., Electronics, Furniture, Stationery)</li>
#     <li><b>Quantity</b>: The number of units purchased for that product</li>
#     <li><b>Price</b>: The price per unit of the product</li>
#     <li><b>Total</b>: The total cost for the product (calculated as Quantity × Price)</li>
#     <li><b>OrderDate</b>: The date when the order was placed</li>
#     <li><b>CustomerCity</b>: The city where the customer resides</li>
#
# </ul>
#
# You can see the dataset here:
#
# <font size="1">
# <table style="font-size:medium; border:1px solid black; border-collapse:collapse;">
#   <tr>
#     <th>OrderID</th>
#     <th>Product</th>
#     <th>Category</th>
#     <th>Quantity</th>
#     <th>Price</th>
#     <th>Total</th>
#     <th>OrderDate</th>
#     <th>CustomerCity</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Laptop</td>
#     <td>Electronics</td>
#     <td>2</td>
#     <td>800</td>
#     <td>1600</td>
#     <td>2022-01-10</td>
#     <td>New York</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Smartphone</td>
#     <td>Electronics</td>
#     <td>3</td>
#     <td>600</td>
#     <td>1800</td>
#     <td>2022-02-15</td>
#     <td>Los Angeles</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Desk Chair</td>
#     <td>Furniture</td>
#     <td>5</td>
#     <td>150</td>
#     <td>750</td>
#     <td>2022-03-12</td>
#     <td>Chicago</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>Notebook</td>
#     <td>Stationery</td>
#     <td>10</td>
#     <td>2</td>
#     <td>20</td>
#     <td>2022-04-05</td>
#     <td>Houston</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>Monitor</td>
#     <td>Electronics</td>
#     <td>1</td>
#     <td>300</td>
#     <td>300</td>
#     <td>2022-05-21</td>
#     <td>Miami</td>
#   </tr>
# </table>
# </font>

# %% [markdown]
# <hr>

# %% [markdown]
# ## Introduction of <code>Pandas</code>

# %%
from prometheus_client import aiohttp
# Dependency needed to install file
# %pip3 install xlrd openpyxl  # use pip3 in local terminal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 from prometheus_client import aiohttp
#       2 # Dependency needed to install file
#       3 get_ipython().run_line_magic('pip3', 'install xlrd openpyxl  # use pip3 in local terminal')
#
# File ~/Library/Python/3.9/lib/python/site-packages/prometheus_client/aiohttp/__init__.py:1
# ----> 1 from .exposition import make_aiohttp_handler
#       3 __all__ = [
#       4     "make_aiohttp_handler",
#       5 ]
#
# File ~/Library/Python/3.9/lib/python/site-packages/prometheus_client/aiohttp/exposition.py:3
#       1 from __future__ import annotations
# ----> 3 from aiohttp import hdrs, web
#       4 from aiohttp.typedefs import Handler
#       6 from ..exposition import _bake_output
#
# ModuleNotFoundError: No module named 'aiohttp'

# %%
# Import required library

import pandas as pd

# %% [markdown]
# After the import command, we now have access to a large number of pre-built classes and functions. This assumes the library is installed; in our lab environment all the necessary libraries are installed. One way pandas allows you to work with data is a dataframe. Let's go through the process to go from a comma separated values (<b>.csv</b>) file to a dataframe. This variable <code>csv_path</code> stores the path of the <b>.csv</b>, that is  used as an argument to the <code>read_csv</code> function. The result is stored in the object <code>df</code>, this is a common short form used for a variable referring to a Pandas dataframe.

# %%
# Read data from CSV file
#
# csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv'
# df = pd.read_csv(csv_path)
# not able to down load any file
from pyodide.http import pyfetch  # with web
import pandas as pd

filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"


async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# await download(filename, "Product-sales.csv")
# df = pd.read_csv("Product-sales.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       1 # Read data from CSV file
#       2 #
#       3 # csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv'
#       4 # df = pd.read_csv(csv_path)
#       5 # not able to down load any file
# ----> 6 from pyodide.http import pyfetch  # with web
#       7 import pandas as pd
#       9 filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"
#
# File ~/Library/Python/3.9/lib/python/site-packages/pyodide/__init__.py:17
#      13 __version__ = "0.25.1"
#      15 __all__ = ["__version__", "console", "code", "ffi", "http", "webloop"]
# ---> 17 from . import _state  # noqa: F401
#      18 from .webloop import _initialize_event_loop
#      20 _initialize_event_loop()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pyodide/_state.py:7
#       3 from typing import Any
#       5 import __main__
# ----> 7 from _pyodide._importhook import jsfinder
#       9 from .ffi import JsProxy
#      12 def save_state() -> dict[str, Any]:
#
# File ~/Library/Python/3.9/lib/python/site-packages/_pyodide/__init__.py:10
#       1 # _pyodide is imported at the very beginning of the initialization process so it
#       2 # cannot import from js, pyodide_js, or _pyodide_core.
#       3 #
#    (...)
#       8 # _pyodide_core belongs in _pyodide. Code that requires such imports belongs in
#       9 # pyodide.
# ---> 10 from . import _base, _importhook
#      12 __all__ = ["_base", "_importhook"]
#
# File ~/Library/Python/3.9/lib/python/site-packages/_pyodide/_base.py:168
#     162     return compile(mod, filename, mode, flags=flags)
#     165 ReturnMode = Literal["last_expr", "last_expr_or_assign", "none"]
# --> 168 class CodeRunner:
#     169     """This class allows fine control over the execution of a code block.
#     170
#     171     It is primarily intended for REPLs and other sophisticated consumers that
#    (...)
#     231     25
#     232     """
#     234     ast: ast.Module
#
# File ~/Library/Python/3.9/lib/python/site-packages/_pyodide/_base.py:240, in CodeRunner()
#     234 ast: ast.Module
#     235 """
#     236 The ast from parsing ``source``. If you wish to do an ast transform,
#     237 modify this variable before calling :py:meth:`CodeRunner.compile`.
#     238 """
# --> 240 code: CodeType | None
#     241 """
#     242 Once you call :py:meth:`CodeRunner.compile` the compiled code will
#     243 be available in the code field. You can modify this variable
#     244 before calling :py:meth:`CodeRunner.run` to do a code transform.
#     245 """
#     247 def __init__(
#     248     self,
#     249     source: str,
#    (...)
#     255     flags: int = 0x0,
#     256 ):
#
# TypeError: unsupported operand type(s) for |: 'type' and 'NoneType'

# %%
import pandas as pd
import httpx  # with ide http
import requests

filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"


async def downloadFileswithRequest(url, filename):
    try:
        # Use requests to get the file content in a stream
        with requests.get(url, stream=True) as r:
            r.raise_for_status()  # Check for bad response (e.g. 404 Not Found)
            # Open the local file in binary write mode ('wb') and save the content in chunks
            open_and_write_file(r, filename)

            print(f"Successfully downloaded and saved: {filename}")

    except requests.exceptions.RequestException as e:
        print(f"An error occurred during download: {e}")
    except IOError as e:
        print(f"An error occurred while saving the file: {e}")
#write file in dir
def open_and_write_file(response, filename):
    with open(filename, "wb") as f:
        # Check if the response object has the 'iter_content' method (requests)
        if hasattr(response, 'iter_content'):
            for chunk in response.iter_content():
                f.write(chunk)
        # Check if the response object has the 'iter_bytes' method (httpx)
        elif hasattr(response, 'iter_bytes'):
            # For httpx, iter_bytes is a method that needs to be called
            for chunk in response.iter_bytes():
                f.write(chunk)
        else:
            raise TypeError("Unsupported response object type. Must be requests or httpx response.")

async def downloadFiles(url, filename):
    with httpx.stream("GET", url, follow_redirects=True) as response:
        response.raise_for_status()  # Stop if the link is broken
        open_and_write_file(response, filename)
#await downloadFiles(filename, "Product-sales.csv")
await downloadFileswithRequest(filename, "Product-sales.csv")
df = pd.read_csv("Product-sales.csv")
# Out:
# Successfully downloaded and saved: Product-sales.csv

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface. While working on the downloaded version of this notebook on their local machines, the learners can simply **skip the steps above**, and simply use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
#filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"
#df = pd.read_csv(filename)

# %% [markdown]
# We can use the method <code>head()</code> to examine the first five rows of a dataframe:

# %%
# Print first five rows of the dataframe

df.head()
# Out:
#    OrderID     Product     Category  Quantity  Price  Total   OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600  2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800  2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750  2022-03-12
# 3        4    Notebook   Stationery        10      2     20  2022-04-05
# 4        5     Monitor  Electronics         1    300    300  2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %% [markdown]
# We use the path of the excel file and the function <code>read_excel</code>. The result is a data frame as before:

# %%
# Read data from Excel File and print the first five rows
import os
xlsx_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n9LOuKI9SlUa1b5zkaCMeg/Product-sales.xlsx'
filename2 = "Product-sales.xlsx"
full_path = os.path.abspath(filename2)
await downloadFiles(xlsx_path, "Product-sales.xlsx")
# await download(xlsx_path, "Product-sales.xlsx")

if os.path.exists(full_path):
    df = pd.read_excel(full_path)
    print(df.head())
else:
    print(f"Error: {filename} was not found at {full_path}")
# df = pd.read_excel("Product-sales.xlsx")
# Out:
#    OrderID     Product     Category  Quantity  Price  Total  OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600 2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800 2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750 2022-03-12
# 3        4    Notebook   Stationery        10      2     20 2022-04-05
# 4        5     Monitor  Electronics         1    300    300 2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface. While working on the downloaded version of this notebook on their local machines, the learners can simply **skip the steps above**, and simply use the URL directly in the `pandas.read_excel()` function. You can uncomment and run the statements in the cell below.

# %%
#xlsx_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n9LOuKI9SlUa1b5zkaCMeg/Product-sales.xlsx'
df = pd.read_excel(xlsx_path)
df.head()
# Out:
#    OrderID     Product     Category  Quantity  Price  Total  OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600 2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800 2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750 2022-03-12
# 3        4    Notebook   Stationery        10      2     20 2022-04-05
# 4        5     Monitor  Electronics         1    300    300 2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %% [markdown]
# We can access the column <b>Quantity</b> and assign it a new dataframe <b>x</b>:

# %%
# Access to the column Length

x = df[['Quantity']]
x

# %% [markdown]
# The process is shown in the figure:

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/CHIJ1eh6tYUzFsmgQIuCSA/1.PNG" width="1150">

# %% [markdown]
# <hr>

# %% [markdown]
# ## Viewing Data and Accessing Data

# %% [markdown]
# You can also get a column as a series. You can think of a Pandas series as a 1-D dataframe. Just use one bracket:

# %%
# Get the column as a series

x = df['Product']
x
# Out:
# 0        Laptop
# 1    Smartphone
# 2    Desk Chair
# 3      Notebook
# 4       Monitor
# Name: Product, dtype: object

# %% [markdown]
# You can also get a column as a dataframe. For example, we can assign the column <b>Quantity</b>:

# %%
# Get the column as a dataframe

x = df[['Quantity']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# You can do the same thing for multiple columns; we just put the dataframe name, in this case, <code>df</code>, and the name of the multiple column headers enclosed in double brackets. The result is a new dataframe comprised of the specified columns:

# %%
# Access to multiple columns

y = df[['Product', 'Category', 'Quantity']]
y
# Out:
#       Product     Category  Quantity
# 0      Laptop  Electronics         2
# 1  Smartphone  Electronics         3
# 2  Desk Chair    Furniture         5
# 3    Notebook   Stationery        10
# 4     Monitor  Electronics         1

# %% [markdown]
# The process is shown in the figure:

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/BiDzVOrMQbianIz9DMum7A/2.PNG" width="1100">

# %% [markdown]
# One way to access unique elements is the <code>iloc</code> method, where you can access the 1st row and the 1st column as follows:

# %%
# Access the value on the first row and the first column

df.iloc[0, 0]
# Out:
# np.int64(1)

# %% [markdown]
# You can access the 2nd row and the 1st column as follows:

# %%
# Access the value on the second row and the first column

df.iloc[1, 0]
# Out:
# np.int64(2)

# %% [markdown]
# You can access the 1st row and the 3rd column as follows:

# %%
# Access the value on the first row and the third column

df.iloc[0, 2]
# Out:
# 'Electronics'

# %%
# Access the value on the second row and the third column
df.iloc[1, 2]
# Out:
# 'Electronics'

# %% [markdown]
# This is shown in the following image

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/npw0rMu2hutg8MdOz4t_Kw/3.PNG" width="750">

# %% [markdown]
# You can access the column using the name as well, the following are the same as above:

# %%
# Access the column using the name

df.loc[0, 'Product']

# %%
# Access the column using the name

df.loc[1, 'Product']

# %%
# Access the column using the name

df.loc[1, 'CustomerCity']

# %%
# Access the column using the name

df.loc[1, 'Total']

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/TR4-yEJdBj9NyQa5rlL6mg/4.PNG" width="750">

# %% [markdown]
# You can perform slicing using both the index and the name of the column:

# %%
# Slicing the dataframe

df.iloc[0:2, 0:3]

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/iyo_KV6ejpqgDxCcd3M1wg/5.PNG" width="950">

# %%
# Slicing the dataframe using name

df.loc[0:2, 'OrderID':'Category']
# Out:
#    OrderID     Product     Category
# 0        1      Laptop  Electronics
# 1        2  Smartphone  Electronics
# 2        3  Desk Chair    Furniture

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/88vCcZQ8N4W_R7WyKoqoAA/6.PNG" width="750">

# %% [markdown]
# <hr>

# %% [markdown]
# ## Quiz on DataFrame

# %% [markdown]
# Use a variable <code>q</code> to store the column <b>Price</b> as a dataframe

# %%
# Write your code below and press Shift+Enter to execute
q = df[["Price"]]
q
# Out:
#    Price
# 0    800
# 1    600
# 2    150
# 3      2
# 4    300

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# q = df[['Price']]
# q
#
# ```
#
# </details>

# %% [markdown]
# Assign the variable <code>q</code> to the dataframe that is made up of the column <b>Product</b> and <b>Category</b>:

# %%
# Write your code below and press Shift+Enter to execute
q = df[["Product", "Category"]]
q
# Out:
#       Product     Category
# 0      Laptop  Electronics
# 1  Smartphone  Electronics
# 2  Desk Chair    Furniture
# 3    Notebook   Stationery
# 4     Monitor  Electronics

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# q = df[['Product', 'Category']]
# q
#
# ```
#
# </details>

# %% [markdown]
# Access the 2nd row and the 3rd column of <code>df</code>:

# %%
# Write your code below and press Shift+Enter to execute
df.iloc[1,2]
# Out:
# 'Electronics'

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.iloc[1, 2]
#
# ```
#
# </details>

# %% [markdown]
# Use the following list to convert the dataframe index <code>df</code> to characters and assign it to <code>df_new</code>; find the element corresponding to the row index <code>a</code> and column  <code>'CustomerCity'</code>. Then select the rows <code>a</code> through <code>d</code> for the column  <code>'CustomerCity'</code>

# %%
new_index = ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df_new=df
# df_new.index=new_index
# df_new.loc['a', 'CustomerCity']
# df_new.loc['a':'d', 'CustomerCity']
#
# ```
#
# </details>

# %% [markdown]
# <hr>
# <h2>The last exercise!</h2>
# <p>Congratulations, you have completed your first lesson and hands-on lab in Python.
# <hr>

# %% [markdown]
# ## Authors:
#
# [Joseph Santarcangelo](https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01)
#
# Joseph Santarcangelo has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
# ## <h3 align="center"> © IBM Corporation 2023. All rights reserved. <h3/>
#
#  Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                 |
# | ----------------- | ------- | ---------- | ---------------------------------- |
# | 2023-11-02 | 2.2 | Abhishek Gagneja | Instructions updated |
# | 2022-01-10        | 2.1     | Malika     | Removed the readme for GitShare    |
# | 2020-08-26        | 2.0     | Lavanya    | Moved lab to course repo in GitLab |
# | 2020-11-24        | 3.0     | Nayef      | Added new images                   |
# |                   |         |            |                                    |
